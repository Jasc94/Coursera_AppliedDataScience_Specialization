# %% [markdown]
# # Week 3 - Assignment

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

# generate 4 random variables from the random, gamma, exponential, and uniform distributions
x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

# plot the histograms
plt.figure(figsize=(9,3))
plt.hist(x1, density=True, bins=20, alpha=0.5)
plt.hist(x2, density=True, bins=20, alpha=0.5)
plt.hist(x3, density=True, bins=20, alpha=0.5)
plt.hist(x4, density=True, bins=20, alpha=0.5);
plt.axis([-7,21,0,0.6])

plt.text(x1.mean()-1.5, 0.5, 'x1\nNormal')
plt.text(x2.mean()-1.5, 0.5, 'x2\nGamma')
plt.text(x3.mean()-1.5, 0.5, 'x3\nExponential')
plt.text(x4.mean()-1.5, 0.5, 'x4\nUniform')
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(15.500440228320443, 0.5, 'x4\nUniform')

# %% [markdown]
# Creates a number of subplots using the pyplot subplots or matplotlib gridspec functionality.

# %%
dif, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex = True, sharey = True)

x1 = np.random.normal(-2.5, 1, 100)
x2 = np.random.gamma(2, 1.5, 100)
x3 = np.random.exponential(2, 100)
x4 = np.random.uniform(14, 20, 100)

ax1.hist(x1, density = True, bins = 10, alpha = 0.5)
ax2.hist(x2, density = True, bins = 10, alpha = 0.5)
ax3.hist(x3, density = True, bins = 10, alpha = 0.5)
ax4.hist(x4, density = True, bins = 10, alpha = 0.5)

ax1.set_title('Normal')
ax2.set_title('Gamma')
ax3.set_title('Exponential')
ax4.set_title('Uniform')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Uniform')

# %%
dif, (ax1, ax2) = plt.subplots(2, 1, sharex = True, sharey = True)

x1 = np.random.normal(-2.5, 1, 100)
x2 = np.random.gamma(2, 1.5, 100)

ax1.hist(x1, density = True, bins = 10, alpha = 0.5)
ax2.hist(x2, density = True, bins = 10, alpha = 0.5)

ax1.set_title('Normal')
ax2.set_title('Gamma')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Gamma')

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

# %matplotlib notebook

n = 100
x = np.random.randn(n)

def update(curr):
    if curr == n:
        a.event_source.stop()
    
    plt.cla()
    # bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins = 10)
    plt.axis([-4, 4, 0, 30])
    
    # Format
    plt.gca().set_title('Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    
    plt.annotate('n = {}'.format(curr), [3, 27])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

# %matplotlib notebook

n = 100
x1 = np.random.randn(n)
x2 = np.random.randn(n)


def update(curr):
    if curr == n:
        a.event_source.stop()
    
    plt.cla()
    # bins = np.arange(-4, 4, 0.5)
    plt.hist(x1[:curr], bins = 10, alpha = 0.5)
    plt.hist(x2[:curr], bins = 10, alpha = 0.5)
    plt.axis([-4, 4, 0, 30])
    
    
    plt.text(x1.mean()-1.5, 0.5, 'x1\nNormal')
    plt.text(x2.mean()-1.5, 0.5, 'x2\nNormal')
    # Format
    plt.gca().set_title('Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    
    plt.annotate('n = {}'.format(curr), [3, 27])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

# %matplotlib notebook

n = 100
x1 = np.random.randn(n)
x2 = np.random.randn(n)


def update(curr):
    if curr == n:
        a.event_source.stop()
    
    plt.cla()
    
    # bins = np.arange(-4, 4, 0.5)
    ax1.hist(x1[:curr], bins = 10, alpha = 0.5)
    ax2.hist(x2[:curr], bins = 10, alpha = 0.5)
    ax1.axis([-4, 4, 0, 30])
    ax2.axis([-4, 4, 0, 30])
    
    
    ax1.text(x1.mean()-1.5, 0.5, 'x1\nNormal')
    ax2.text(x2.mean()-1.5, 0.5, 'x2\nNormal')
    # Format
    ax1.gca().set_title('Distribution')
    ax1.gca().set_ylabel('Frequency')
    ax1.gca().set_xlabel('Value')
    ax1.annotate('n = {}'.format(curr), [3, 27])
    
    ax2.gca().set_title('Distribution')
    ax2.gca().set_ylabel('Frequency')
    ax2.gca().set_xlabel('Value')
    ax2.annotate('n = {}'.format(curr), [3, 27])

# %%
dif, (ax1, ax2) = plt.subplots(2, 1, sharex = True, sharey = True)

a = animation.FuncAnimation(dif, update, interval = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Creates an animation, pulling between 100 and 1000 samples from each of the random variables (x1, x2, x3, x4) for each plot and plotting this as we did in the lecture on animation.

# %%
import matplotlib.animation as animation

n = 100

x = np.random.randn(n)

def update(curr):
    # First, we check if the current frame is at the end of our list
    if curr == n:
        # If so, we need to tell the animation to stop, what we do by calling the stop
        # object on the event source object attached to the FuncAnimation object
        # We call our animation 'a'
        a.event_source.stop()
        
    # First, we clear the current axis with cla()
    plt.cla()
    # We consider the bins, by passing in the spacing in between bins, instead of the number
    # of them that we want
    bins = np.arange(-4, 4, 0.5)
    # Then, we create a histogram using a set of value in the x up to the current value.
    # Here slicing is great
    plt.hist(x[:curr], bins = bins)
    # We also need to set the axis values since otherwise, the histogram will continually
    # autoscale between frames
    plt.axis([-4, 4, 0, 30])
    
    # Then, some formatting
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    # We can add some extra text to the graph
    plt.annotate('n = {}'.format(curr), [3, 27])

# %%
# Let's generate the figure now
fig = plt.figure()
# Then, we call the FuncAnimation constructor and assign this to the variable a
# 1st parameter -> figure we are working with
# 2nd paramater -> our function
# 3rd parameter -> Amount of time we want between updates (in miliseconds)
a = animation.FuncAnimation(fig, update, interval = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook


n = 100

# Generate 4 random variables from the normal, gamma, exponential,
# and uniform
x1 = np.random.normal(0, 1, n)
x2 = np.random.gamma(2, 1.5, n)
x3 = np.random.exponential(2, n)
x4 = np.random.uniform(14, 20, n)

def update(curr):
    if curr == n:
        a.event_source.stop()
    
    b = 10
    
    ax1.set_ylim(0, 0.4)
    ax1.hist(x1[:curr], bins = b, c = 'r')
    ax2.hist(x2[:curr], bins = b, c = 'b')
    ax3.hist(x3[:curr], bins = b, c = 'g')
    ax4.hist(x4[:curr], bins = b, c = 'y')
    
    ax1.set_title('Normal')
    ax2.set_title('Gamma')
    ax3.set_title('Exponential')
    ax4.set_title('Uniform')
    
    fig.tight_layout(h_pad = 1, w_pad = 1)
    
    return ax1, ax2, ax3, ax3

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2,
                                             sharey = True)

a = animation.FuncAnimation(fig, update, interval = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# MEJOR SOLUCIÓN DE MOMENTO

import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

n = 100

# generate 4 random variables from the random, gamma, exponential, and uniform distributions
x1 = np.random.normal(-2.5, 1, n)
x2 = np.random.gamma(2, 1.5, n)
x3 = np.random.exponential(2, n)
x4 = np.random.uniform(14,20, n)

def update(curr):
    # check if animation is at the last frame, and if so, stop the animation a
    if curr == n: 
        a.event_source.stop()
    
    b = 10
    
    #ax1.set_ylim(0, 0.4)
    ax1.hist(x1[:curr], bins=b, color="tomato")
    ax1.set_title("Normal, n = {}".format(curr))
    ax2.hist(x2[:curr], bins=b, color="aquamarine")
    ax2.set_title("Gamma")
    #ax2.set_xlim(0,15)
    ax3.hist(x3[:curr], bins=b, color="lawngreen")
    ax3.set_title("Exponential")
    #ax3.set_xlim(7,20)
    ax4.hist(x4[:curr], bins=b, color="gold")
    ax4.set_title("Uniform")
    #ax4.set_xlim(14,20)
    
    #ax1.legend(loc = 4, frameon = false, title = 'n = {}'.format(curr))
    
    fig.tight_layout(h_pad=1, w_pad = 1)
    
    return ax1, ax2, ax3, ax4

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey = True)

a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="640">
