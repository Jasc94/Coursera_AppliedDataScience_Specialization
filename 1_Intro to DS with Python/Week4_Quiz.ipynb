# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Q1

# %%
import numpy as np

a = np.arange(8)
b = a[4:6]
b[:] = 40
c = a[4] + a[6]
c
# Out:
# 46

# %% [markdown]
# # Q2

# %%
s = 'ABCAC'

# %%
bool(re.match('A', s)) == True
# Out:
# True

# %% [markdown]
# # Q3

# %%
def result():
    s = 'ACAABAACAAABACDBADDDFSDDDFFSSSASDAFAAACBAAAFASD'

    result = []
    # compete the pattern below
    pattern = '(?<=[B-Z])A{3}'
    for item in re.finditer(pattern, s):
      # identify the group number below.
      result.append(item.group())
      
    return result

# %%
result()
# Out:
# ['AAA', 'AAA', 'AAA']

# %%
index = ['d', 'b', 'a', 'c']
l = [4, 7, -5, 3]
df = pd.Series(l, index = index)
df
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %% [markdown]
# # Q4

# %%
df.index[0]
# Out:
# 'd'

# %% [markdown]
# # Q5

# %%
d1 = {'Mango' : 20, 'Strawberry' : 15, 'Blueberry' : 18, 'Vanilla' : 31}
d2 = {'Strawberry' : 20, 'Vanilla' : 30, 'Banana' : 15, 'Mango' : 20, 'Plain' : 20}

s1 = pd.Series(d1)
s2 = pd.Series(d2)

s3 = s1.add(s2)
s3
# Out:
# Banana         NaN
# Blueberry      NaN
# Mango         40.0
# Plain          NaN
# Strawberry    35.0
# Vanilla       61.0
# dtype: float64

# %%
s3['Mango'] >=  s1.add(s2, fill_value = 0)['Mango']
# Out:
# True

# %%
s3
# Out:
# Banana         NaN
# Blueberry      NaN
# Mango         40.0
# Plain          NaN
# Strawberry    35.0
# Vanilla       61.0
# dtype: float64

# %% [markdown]
# # Q6

# %%
nhl_df = pd.read_csv("./Course1_Resources/assignments/assignment4/assets/nhl.csv")
nhl_df.head()
# Out:
#                    team                 GP                  W  \
# 0     Atlantic Division  Atlantic Division  Atlantic Division
# 1  Tampa Bay Lightning*                 82                 54
# 2        Boston Bruins*                 82                 50
# 3  Toronto Maple Leafs*                 82                 49
# 4      Florida Panthers                 82                 44
#
#                    L                 OL                PTS               PTS%  \
# 0  Atlantic Division  Atlantic Division  Atlantic Division  Atlantic Division
# 1                 23                  5                113               .689
# 2                 20                 12                112               .683
# 3                 26                  7                105               .640
# 4                 30                  8                 96               .585
#
#                   GF                 GA                SRS                SOS  \
# ...

# %%
nhl_df.set_index('GP')
# Out:
#                                    team                  W                  L  \
# GP
# Atlantic Division     Atlantic Division  Atlantic Division  Atlantic Division
# 82                 Tampa Bay Lightning*                 54                 23
# 82                       Boston Bruins*                 50                 20
# 82                 Toronto Maple Leafs*                 49                 26
# 82                     Florida Panthers                 44                 30
# ...                                 ...                ...                ...
# 82                   Los Angeles Kings*                 46                 28
# 82                      Phoenix Coyotes                 37                 30
# 82                    Vancouver Canucks                 36                 35
# 82                       Calgary Flames                 35                 40
# 82                      Edmonton Oilers                 29                 44
#
# ...

# %% [markdown]
# # Q7

# %%
S = pd.Series(np.arange(5), index=['a', 'b', 'c', 'd', 'e'])
S
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
S['b':'e']
# Out:
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %% [markdown]
# # Q8

# %%
R1 = [5, 6, 20]
R2 = [5, 82, 28]
R3 = [71, 31, 92]
R4 = [67, 37, 49]

R1 = pd.Series(R1)
R2 = pd.Series(R2)
R3 = pd.Series(R3)
R4 = pd.Series(R4)

index = ['a', 'b', 'c']

df = pd.DataFrame([R1, R2, R3, R4])
df.columns = index
df
# Out:
#     a   b   c
# 0   5   6  20
# 1   5  82  28
# 2  71  31  92
# 3  67  37  49

# %%
f = lambda x: x.max() + x.min()
df_new = df.apply(f)
df_new[1]
# Out:
# 88

# %% [markdown]
# # Q9

# %%
df = pd.read_csv('../Intro to DS with Python/Course1_Resources/resources/week-3/datasets/cwurData.csv')

# Let's say we want to create a new column called Rank_Level, where institutions with world
# ranking:
# 1 - 100 -> First tier
# 101 - 200 -> Second tier
# 201 - 300 -> Third tier
# after 301 -> Other top universities

# We will create a function called create_category which will operate on the first column in
# the dataframe, world_rank

def create_category(ranking):
    # Since the rank is just an integer, we can just do a bunch of if/elif
    if (ranking >=1) & (ranking < 100):
        return 'First Tier Top University'
    elif (ranking >= 101) & (ranking < 200):
        return 'Second Tier Top University'
    elif (ranking >= 201) & (ranking < 300):
        return 'Third Tier Top University'
    else:
        return 'Other Top University'
    
# Now we can apply this to a single column of data to create a new series
df['Rank_Level'] = df['world_rank'].apply(lambda x: create_category(x))
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year  \
# ...

# %%
df2 = df.pivot_table(values = 'score', index = 'country', columns = 'Rank_Level',
               aggfunc = [np.mean, np.max], margins = True)
df2
# Out:
#                                           mean                       \
# Rank_Level           First Tier Top University Other Top University
# country
# Argentina                                  NaN            44.672857
# Australia                            47.942500            44.645750
# Austria                                    NaN            44.864286
# Belgium                              51.875000            45.081000
# Brazil                                     NaN            44.499706
# Bulgaria                                   NaN            44.335000
# Canada                               53.633846            44.760541
# Chile                                      NaN            44.767500
# China                                53.592500            44.564267
# Colombia                                   NaN            44.432500
# Croatia                                    NaN            44.770000
# Cyprus                                     NaN            44.210000
# ...

# %%
df2.unstack().unstack()
# Out:
# country                          Argentina  Australia    Austria    Belgium  \
#      Rank_Level
# mean First Tier Top University         NaN  47.942500        NaN  51.875000
#      Other Top University        44.672857  44.645750  44.864286  45.081000
#      Second Tier Top University        NaN  49.242500        NaN  49.084000
#      Third Tier Top University         NaN  47.285000  47.066667  46.746667
#      All                         44.672857  45.825517  45.139583  47.011000
# amax First Tier Top University         NaN  51.610000        NaN  52.030000
#      Other Top University        45.660000  45.970000  46.290000  46.210000
#      Second Tier Top University        NaN  50.400000        NaN  49.730000
#      Third Tier Top University         NaN  47.470000  47.780000  47.140000
#      All                         45.660000  51.610000  47.780000  52.030000
#
# country                             Brazil  Bulgaria     Canada    Chile  \
#      Rank_Level
# ...

# %% [markdown]
# # Q10

# %%
d1 = {'Item' : 'item_1', 'Store' : 'A', 'Quantity sold' : 10.0}
d2 = {'Item' : 'item_1', 'Store' : 'B', 'Quantity sold' : 20.0}
d3 = {'Item' : 'item_1', 'Store' : 'C', 'Quantity sold' : np.nan}
d4 = {'Item' : 'item_2', 'Store' : 'A', 'Quantity sold' : 5.0}
d5 = {'Item' : 'item_2', 'Store' : 'B', 'Quantity sold' : 10.0}
d6 = {'Item' : 'item_2', 'Store' : 'C', 'Quantity sold' : 15.0}

s1 = pd.Series(d1)
s2 = pd.Series(d2)
s3 = pd.Series(d3)
s4 = pd.Series(d4)
s5 = pd.Series(d5)
s6 = pd.Series(d6)

df = pd.DataFrame([s1, s2, s3, s4, s5, s6])
df
# Out:
#      Item Store  Quantity sold
# 0  item_1     A           10.0
# 1  item_1     B           20.0
# 2  item_1     C            NaN
# 3  item_2     A            5.0
# 4  item_2     B           10.0
# 5  item_2     C           15.0

# %%
df.groupby('Item').sum().iloc[0]['Quantity sold']
# Out:
# 30.0
